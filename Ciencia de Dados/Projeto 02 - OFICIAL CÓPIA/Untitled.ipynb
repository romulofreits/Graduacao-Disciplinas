# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
x = c(1,2,3)
x
# Out:
# [1] 1 2 3

# %%
f = function(x) dnorm(x, 20, 4) 
a = plot(f, 0, 30)
# Out:
# plot without title

# %%
f = function(x) dnorm(x, 20, 4)
plot(f, 0, 30)
png('image.png')
plot(f, 0, 30)
dev.off()
# Out:
# png
#   2
# plot without title
