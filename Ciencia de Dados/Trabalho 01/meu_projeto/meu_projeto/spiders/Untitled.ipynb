# %%
try: # Checando se Scrapy está instalado
    import scrapy
except:
    # !pip install scrapy
    import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings

# %%
urls = ['https://www.ibge.gov.br/cidades-e-estados/ce/Abaiara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Acarape.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Acarau.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Acopiara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aiuaba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Alcantaras.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Altaneira.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Alto-Santo.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Amontada.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Antonina-do-Norte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Apuiares.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aquiraz.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aracati.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aracoiaba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ararenda.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Araripe.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aratuba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Arneiroz.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Assare.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aurora.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Baixio.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Banabuiu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Barbalha.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Barreira.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Barro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Barroquinha.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Baturite.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Beberibe.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Bela-Cruz.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Boa-Viagem.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Brejo-Santo.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Camocim.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Campos-Sales.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Caninde.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Capistrano.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Caridade.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Caririacu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Carire.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Carius.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Carnaubal.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Cascavel.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Catarina.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Catunda.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Caucaia.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Cedro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Chaval.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Chorozinho.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Choro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Coreau.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Crateus.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Crato.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Croata.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Cruz.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Deputado-Irapuan-Pinheiro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Erere.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Eusebio.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Farias-Brito.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Forquilha.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Fortaleza.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Fortim.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Frecheirinha.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Gereral-Sampaio.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Granja.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Granjeiro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Graca.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Groairas.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Guaiuba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Guaraciaba-do-Norte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Guaramiranga.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Hidrolandia.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Horizonte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ibaretama.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ibiapina.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ibicuitinga.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Icapui.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ico.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Iguatu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Independencia.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ipaporanga.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ipaumirim.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ipu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ipueiras.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Iracema.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Iraucuba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Itaicaba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Itaitinga.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Itapaje.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Itapipoca.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Itapiuna.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Itarema.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Itatira.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jaguaretama.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jaguaribara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jaguaribe.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jaguaruana.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jardim.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jati.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jijoca-de-Jericoacoara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Juazeiro-do-Norte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Jucas.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Lavras-da-Mangabeira.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Limoeiro-do-Norte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Madalena.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Maracanau.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Maranguape.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Marco.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Martinolope.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Massape.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Mauriti.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Meruoca.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Milagres.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Milha.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Miraima.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Missao-Velha.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Mombaca.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Monsenhor-Tabosa.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Morada-Nova.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Moraujo.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Morrinhos.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Mucambo.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Mulungu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Nova-Olinda.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Nova-Russas.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Novo-Oriente.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ocara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Oros.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pacajus.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pacatuba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pacoti.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pacuja.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Palhano.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Palmacia.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Paracuru.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Paraipaba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Parambu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Paramoti.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pedra-Branca.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Penaforte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pentecoste.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pereiro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pindoretama.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Piquet-Carneiro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Pires-Ferreira.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Poranga.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Porteiras.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Potengi.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Potiretama.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Quiterianopolis.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Quixada.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Quixelo.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Quixeramobim.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Quixere.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Redencao.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Reriutaba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Russas.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Saboeiro.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Salitre.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Santa-Quiteria.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Santana-do-Acarau.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Santana-do-Cariri.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Senador-Pompeu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Senador-Sa.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Sobral.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Solonopole.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Sao-Benedito.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Sao-Goncalo-do-Amarante.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Sao-Joao-do-Jaguaribe.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Sao-Luis-do-Curu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Tabuleiro-do-Norte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Tamboril.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Tarrafas.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Taua.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Tejucuoca.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Tiangua.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Trairi.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Tururu.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ubajara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Umari.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Umirim.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Uruburetama.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Uruoca.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Varjota.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Varzea-Alegre.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Vicosa-do-Ceara.html']

# %%
print(urls)
# Out:
# ['https://www.ibge.gov.br/cidades-e-estados/ce/Abaiara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Acarape.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Acarau.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Acopiara.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aiuaba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Alcantaras.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Altaneira.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Alto-Santo.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Amontada.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Antonina-do-Norte.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Apuiares.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aquiraz.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aracati.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Aracoiaba.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Ararenda.html', 'https://www.ibge.gov.br/cidades-e-estados/ce/Araripe.html',
# ...

# %%
import scrapy

class MunicipiosSpider(scrapy.Spider):
    name = "municipios"
    
    start_urls = urls
    
    def parse(self, response):
        prefeito = response.css(".prefeito dd::text").get()
        gentilico = response.css(".gentilico dd::text").get()
        area_territorial = response.css(".area-territorial dd::text").get()
        populacao_estimada = response.css(".estimativa-populacao dd::text").get()
        densidade_demografica = response.css(".densidade-populacional dd::text").get()
        escolarizacao = response.css(".indice-escolarizacao dd::text").get()
        idhm = response.css(".idhm-municipal dd::text").get()
        mortalidade_infantil = response.css(".mortalidade-infantil dd::text").get()
        receitas_realizadas = response.css(".receitas-realizadas dd::text").get()
        despesas_empenhadas = response.css(".despesas-empenhadas dd::text").get()
        pib_per_capita = response.css(".pib-per-capita dd::text").get()
        
        yield {
            "prefeito": prefeito,
            "gentilico": gentilico,
            "area_territorial": area_territorial,
            "populacao_estimada": populacao_estimada,
            "densidade_demografica": densidade_demografica,
            "escolarizacao": escolarizacao,
            "idhm": idhm,
            "mortalidade_infantil": mortalidade_infantil,
            "receitas_realizadas": receitas_realizadas,
            "despesas_empenhadas": despesas_empenhadas,
            "pib_per_capita": pib_per_capita,
            "url": response.url,
        }
        /html/body/main/section/div[2]/div/div[2]/div[2]/div[2]/ul/li[1]/div/p

# %%
#from scrapy.crawler import CrawlerProcess
#from meu_projeto.spiders.municipios_spider import MunicipiosSpider

process = CrawlerProcess()
process.crawl(MunicipiosSpider)
process.start()
# Out:
# 2023-05-07 21:18:12 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2023-05-07 21:18:12 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1q  5 Jul 2022), cryptography 37.0.1, Platform Windows-10-10.0.19045-SP0
# 2023-05-07 21:18:12 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-07 21:18:12 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-05-07 21:18:12 [scrapy.extensions.telnet] INFO: Telnet Password: f69120aac6adbfce
# 2023-05-07 21:18:12 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-07 21:18:13 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ...
